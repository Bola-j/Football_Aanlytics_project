# %%
import os
import pandas as pd

def extract_col(col):
    return col[1] if isinstance(col, tuple) else col

def scrape_team(html_file):
    team_name = html_file.replace("_possession.html", "").replace("_", " ")

    with open(html_file, "r", encoding="utf-8") as f:
        html = f.read()

    tables = pd.read_html(html)
    t0 = tables[0]
    t0.columns = [extract_col(c) for c in t0.columns]

    df = t0[["Date","Venue","Opponent","Result","GF","GA","Poss"]].copy()
    df["Team"] = team_name
    df = df[["Team","Date","Venue","Opponent","Result","GF","GA","Poss"]]

    # remove Totals row
    df = df.iloc[:-1, :]
    return df

html_files = [f for f in os.listdir() if f.lower().endswith(".html")]

dfs = []
for f in html_files:
    try:
        d = scrape_team(f)
        dfs.append(d)
        print(f, "rows:", len(d))
    except Exception as e:
        print(f, e)

league_df = pd.concat(dfs, ignore_index=True)
league_df.to_csv("../../data_raw/Premeier_League_possession_2023_2024.csv", index=False)

print("DONE rows:", len(league_df), "teams:", league_df["Team"].nunique())
# Out:
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_33304\3706464088.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_33304\3706464088.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_33304\3706464088.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# ...

# %%
pl = pd.read_csv('Premeier_League_possession_2023_2024.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pl = pd.read_csv('Premeier_League_possession_2023_2024.csv')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
pl
# Out:
#                         Team        Date Venue         Opponent Result  GF  \
# 0                    Arsenal  2023-08-12  Home  Nott'ham Forest      W   2
# 1                    Arsenal  2023-08-21  Away   Crystal Palace      W   1
# 2                    Arsenal  2023-08-26  Home           Fulham      D   2
# 3                    Arsenal  2023-09-03  Home   Manchester Utd      W   3
# 4                    Arsenal  2023-09-17  Away          Everton      W   1
# ..                       ...         ...   ...              ...    ...  ..
# 755  Wolverhampton Wanderers  2024-04-24  Home      Bournemouth      L   0
# 756  Wolverhampton Wanderers  2024-04-27  Home       Luton Town      W   2
# 757  Wolverhampton Wanderers  2024-05-04  Away  Manchester City      L   1
# 758  Wolverhampton Wanderers  2024-05-11  Home   Crystal Palace      L   1
# 759  Wolverhampton Wanderers  2024-05-19  Away        Liverpool      L   0
#
#      GA  Poss
# 0     1  78.0
# 1     0  53.0
# 2     2  71.0
# ...
