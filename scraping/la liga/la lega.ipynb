# %%
import os
import pandas as pd

def extract_col(col):
    return col[1] if isinstance(col, tuple) else col

def scrape_team(html_file):
    team_name = html_file.replace("_possession.html", "").replace("_", " ")

    with open(html_file, "r", encoding="utf-8") as f:
        html = f.read()

    tables = pd.read_html(html)
    t0 = tables[0]
    t0.columns = [extract_col(c) for c in t0.columns]

    df = t0[["Date","Venue","Opponent","Result","GF","GA","Poss"]].copy()
    df["Team"] = team_name
    df = df[["Team","Date","Venue","Opponent","Result","GF","GA","Poss"]]

    # remove Totals row
    df = df.iloc[:-1, :]
    return df

html_files = [f for f in os.listdir() if f.lower().endswith(".html")]

dfs = []
for f in html_files:
    try:
        d = scrape_team(f)
        dfs.append(d)
        print(f, "rows:", len(d))
    except Exception as e:
        print(f, e)

league_df = pd.concat(dfs, ignore_index=True)
league_df.to_csv("../../data_raw/La_Liga_possession_2023_2024.csv", index=False)

print("DONE rows:", len(league_df), "teams:", league_df["Team"].nunique())
# Out:
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Alavés_possession.html rows: 38
# Almería_possession.html rows: 38
# Athletic_Club_possession.html rows: 38
# Atlético_Madrid_possession.html rows: 38
# Barcelona_possession.html rows: 38
# Celta_Vigo_possession.html rows: 38
# Cádiz_possession.html rows: 38
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Getafe_possession.html rows: 38
# Girona Match_possession.html rows: 38
# Granada_possession.html rows: 38
# La_Palmas_possession.html.html rows: 38
# Mallorca_possession.html rows: 38
# Osasuna_possession.html rows: 38
# Rayo Vallecano_possession.html rows: 38
# Real_Betis _possession.html rows: 38
# Real_Madrid _Possession.html rows: 38
# Real_Sociedad_possession.html rows: 38
# Sevilla_possession.html rows: 38
# Valencia_possession.html rows: 38
# Villarreal_possession.html rows: 38
# DONE rows: 760 teams: 20
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Bola_Gerges\AppData\Local\Temp\ipykernel_11884\3007249362.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)

# %%
ll = pd.read_csv('La_Liga_possession_2023_2024.csv')

# %%
ll
# Out:
#            Team        Date Venue        Opponent Result  GF  GA  Poss
# 0        Alavés  2023-08-14  Away           Cádiz      L   0   1  55.0
# 1        Alavés  2023-08-21  Home         Sevilla      W   4   3  34.0
# 2        Alavés  2023-08-28  Away          Getafe      L   0   1  53.0
# 3        Alavés  2023-09-02  Home        Valencia      W   1   0  40.0
# 4        Alavés  2023-09-15  Away  Rayo Vallecano      L   0   2  49.0
# ..          ...         ...   ...             ...    ...  ..  ..   ...
# 755  Villarreal  2024-05-05  Away      Celta Vigo      L   2   3  47.0
# 756  Villarreal  2024-05-11  Home         Sevilla      W   3   2  59.0
# 757  Villarreal  2024-05-14  Away          Girona      W   1   0  33.0
# 758  Villarreal  2024-05-19  Home     Real Madrid      D   4   4  43.0
# 759  Villarreal  2024-05-25  Away         Osasuna      D   1   1  57.0
#
# [760 rows x 8 columns]
